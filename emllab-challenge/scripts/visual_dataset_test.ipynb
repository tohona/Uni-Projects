# %%
import challenge.utils.dataloader as dl
#loader = dl.COCODataLoaderPerson(data_dir='../data/', train=True, batch_size=64, more_augmentation=True)
loader = dl.VOCDataLoaderPerson(data_dir='../data', train=False, more_augmentation=True)

# %%
from challenge.utils.viz import display_result

for idx, (input, target) in enumerate(loader):
    
    display_result(input, None, target, file_path='delete_me.png', pad=0, show_labels=False)

    if idx == 19:
        break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/uni/emllab/emllab-challenge/venv/lib/python3.11/site-packages/PIL/ImageFile.py:503, in _save(im, fp, tile, bufsize)
#     502 try:
# --> 503     fh = fp.fileno()
#     504     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       1 from challenge.utils.viz import display_result
#       3 for idx, (input, target) in enumerate(loader):
# ----> 5     display_result(input, None, target, file_path='delete_me.png', pad=0, show_labels=False)
#       7     if idx == 19:
#       8         break
#
# File ~/uni/emllab/emllab-challenge/challenge/utils/viz.py:80, in display_result(image, output, target, file_path, pad, show_labels)
# ...

# %%
# image 60556 of the coco training set is broken
for i in range(60555, 60557):
    image, target = loader.dataset[i]
    print(i)
